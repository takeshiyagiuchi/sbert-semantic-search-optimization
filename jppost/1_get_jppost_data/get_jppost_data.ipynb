# %%
# !wget -P . https://www.post.japanpost.jp/zipcode/dl/kogaki/zip/ken_all.zip
# Out:
# --2023-05-01 04:49:58--  https://www.post.japanpost.jp/zipcode/dl/kogaki/zip/ken_all.zip
# Resolving www.post.japanpost.jp (www.post.japanpost.jp)... 43.253.48.17
# Connecting to www.post.japanpost.jp (www.post.japanpost.jp)|43.253.48.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1691654 (1.6M) [application/zip]
# Saving to: ‘./ken_all.zip’
#
# ken_all.zip         100%[===================>]   1.61M  --.-KB/s    in 0.04s
#
# 2023-05-01 04:49:58 (42.2 MB/s) - ‘./ken_all.zip’ saved [1691654/1691654]

# %%
# !ls -la .
# Out:
# total 1672
# drwxr-xr-x  3 root root    4096 May  1 04:50 .
# drwxr-xr-x 15 root root    4096 May  1 04:27 ..
# drwxr-xr-x  2 root root    4096 May  1 04:11 .ipynb_checkpoints
# -rw-r--r--  1 root root    3755 May  1 04:50 get_jppost_data.ipynb
# -rw-r--r--  1 root root 1691654 Apr 28 07:59 ken_all.zip

# %%
# !unzip ./ken_all.zip -d ../../datasets/jppost/
# Out:
# Archive:  ./ken_all.zip
#   inflating: ../../datasets/jppost/KEN_ALL.CSV
