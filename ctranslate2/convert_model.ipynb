# %%
# https://opennmt.net/CTranslate2/guides/transformers.html
# https://opennmt.net/CTranslate2/quantization.html

# %%
# !pip install ctranslate2 OpenNMT-py==2.* sentencepiece

# %%
# !ct2-transformers-converter --model ../fine-tuning/tuned_models/multil_vocab-added_jppost-cp-e1-b512_jsts-100-cp-e1to5-b1/checkpoints/37353 --quantization int8_float32 --output_dir converted_models/multil-i8f32

# %%
# !ct2-transformers-converter --model sonoisa/sentence-bert-base-ja-mean-tokens-v2 --quantization int8_float32 --output_dir converted_models/sonoisa-i8f32

# %%
# !ct2-transformers-converter --model ../fine-tuning/tuned_models/tohoku-bb2_jppost-cp-e1-b512_jsts-100-cp-e1to5-b1/checkpoints/37353 --quantization int8_float32 --output_dir converted_models/tohoku-bb2-i8f32

# %%
# !ct2-transformers-converter --model ../fine-tuning/tuned_models/tohoku-bbwwm_vocab-added_jppost-cp-e1-b512_jsts-100-cp-e1to5-b1/checkpoints/37353 --quantization int8_float32 --output_dir converted_models/tohoku-bbwwm-i8f32

# %%
# !ct2-transformers-converter --model ../fine-tuning/tuned_models/izumil_jppost-cp-e1-b512_jsts-100-cp-e1to5-b1/checkpoints/37353 --quantization int8_float32 --output_dir converted_models/izumil-i8f32
